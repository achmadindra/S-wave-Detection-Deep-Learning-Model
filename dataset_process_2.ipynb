# %% [markdown]
# # Proses Pengolahan Dataset (STEAD) 2

# %% [markdown]
# ## Fungsi dan inisialisasi

# %% [markdown]
# Fungsi untuk membuat obspy stream dari dataset yang ada

# %%
import obspy
import h5py
from obspy import UTCDateTime
import numpy as np
from npy_append_array import NpyAppendArray
from obspy.clients.fdsn.client import Client
import matplotlib.pyplot as plt
import time

def make_stream(dataset):
    '''
    input: hdf5 dataset
    output: obspy stream

    '''
    
    data = np.array(dataset)

    tr_E = obspy.Trace(data=data[:, 0])
    tr_E.stats.starttime = UTCDateTime(dataset.attrs['trace_start_time'])
    tr_E.stats.delta = 0.01
    tr_E.stats.channel = dataset.attrs['receiver_type']+'E'
    tr_E.stats.station = dataset.attrs['receiver_code']
    tr_E.stats.network = dataset.attrs['network_code']

    tr_N = obspy.Trace(data=data[:, 1])
    tr_N.stats.starttime = UTCDateTime(dataset.attrs['trace_start_time'])
    tr_N.stats.delta = 0.01
    tr_N.stats.channel = dataset.attrs['receiver_type']+'N'
    tr_N.stats.station = dataset.attrs['receiver_code']
    tr_N.stats.network = dataset.attrs['network_code']

    tr_Z = obspy.Trace(data=data[:, 2])
    tr_Z.stats.starttime = UTCDateTime(dataset.attrs['trace_start_time'])
    tr_Z.stats.delta = 0.01
    tr_Z.stats.channel = dataset.attrs['receiver_type']+'Z'
    tr_Z.stats.station = dataset.attrs['receiver_code']
    tr_Z.stats.network = dataset.attrs['network_code']

    stream = obspy.Stream([tr_E, tr_N, tr_Z])

    return stream

# %% [markdown]
# Preprocessing (filter)

# %%
def FetchingAndFiltering(st):
    '''
    input: obspy stream
    output: filtered traces (E,N,Z) and unfiltered Z trace

    '''
    
    #Pick the traces from the stream object
    trE = st[0]
    trN = st[1]
    trZ = st[2]
        
    #Filter signal
    trE_filt = trE.copy()
    trN_filt = trN.copy()
    trZ_filt = trZ.copy()
    trE_filt.filter("bandpass", freqmin = 0.1, freqmax = 15)
    trN_filt.filter("bandpass", freqmin = 0.1, freqmax = 15)
    trZ_filt.filter("bandpass", freqmin = 0.1, freqmax = 15)
    #Access the attribute of each trace to get the numpy
    dataE = trE_filt.data
    dataN = trN_filt.data
    dataZ = trZ_filt.data

    return dataE,dataN,dataZ,trZ

# %% [markdown]
# Proses pelabelan data

# %%
def Labeling(train_samples,x,y,temp_label, temp_label_2):
    '''
    input: number of training samples, number of train_windows_samples, number of moving_windows_samples, array of initialization label,
        and temp_label_2 array (?)
    output: temp_label_2 array

    '''
    for i in range(train_samples):
        found = 0
        for j in range(i*y,i*y+x):
            if(temp_label[j]==1):
                #Just for the middle and forward for 1
                if(j >= (i*y + int(x/2))):
                    found = 1
                    break
        temp_label_2 = np.append(temp_label_2, found)
    
    return temp_label_2

# %% [markdown]
# Proses menambahkan data domain frekuensi

# %%
def Appending(train_samples, dataE, dataN, dataZ, x , y, temp_signal, pointer_dataset):
    '''
    input: number of training samples, data obspy trace ENZ, number of train_windows_samples, number of moving_windows_samples, 
        and temp_signal (?)
    output: temp_label_2 array

    '''
    pointer = pointer_dataset
    
    for i in range(train_samples):
        
        # Fuse the E,N, and Z channels with the frequency domain too
        temp = np.array([dataE[i*y:i*y+x], dataN[i*y:i*y+x], dataZ[i*y:i*y+x], (dct(dataE[i*y:i*y+x],norm = 'ortho')), (dct(dataN[i*y:i*y+x],norm = 'ortho')), (dct(dataZ[i*y:i*y+x],norm = 'ortho'))])
        temp2 = np.transpose(temp)
                
        # Insert it!
        temp_signal[pointer,:,:] = temp2
        
        # update pointer in temp_signal
        pointer = pointer + 1
            
    return temp_signal

# %% [markdown]
# Proses balancing dataset dengan SMOTE

# %%
def Balancing(temp_signal, temp_label_2, signal_dataset, label_dataset):
    '''
    input: unbalanced processed dataset (signal and label)
    output: balanced dataset (signal and label)

    '''
#     balance_time = time.time()
    
    #Balancing
    orig_shape = temp_signal.shape
#     print(f'before balancing label shape: {temp_label_2.shape}')
#     print(f'before balancing signal shape: {orig_shape}')

    #Reshape it to 2D matrix first
    temp_signal = np.reshape(temp_signal, (temp_signal.shape[0], -1))
#     print(temp_signal.shape)

    #Do the Balancing
    from imblearn.under_sampling import RandomUnderSampler
    from imblearn.over_sampling import SMOTE

    over = SMOTE(sampling_strategy=0.03) #3%
    under = RandomUnderSampler(sampling_strategy=0.8) #50% bigger than minority

    from imblearn.pipeline import Pipeline
    steps = [('o', over), ('u', under)]
    pipeline = Pipeline(steps=steps)

    # transform the dataset
    temp_signal, temp_label_2 = pipeline.fit_resample(temp_signal, temp_label_2)
        
    temp_signal = np.reshape(temp_signal, (-1, orig_shape[1], orig_shape[2]))
#     print(f'after balancing shape: {temp_signal.shape}')
        
    # Save to dataset and update pointer
    signal_dataset = np.append(signal_dataset, temp_signal, axis = 0)
    label_dataset = np.append(label_dataset, temp_label_2, axis = 0)
#     pointer_dataset_inc = len(temp_label2)
#     print(f'pointer_dataset_inc: {pointer_dataset_inc}')
    
#     print(f'Balancing time: {time.time()-balance_time}')

    return signal_dataset, label_dataset

# %%
def SaveToFile(signal_dataset, label_dataset, signal_file, label_file):
    '''
    Saving dataset to external file. Appending to whatever inside the external file
    input: processed dataset (signal and label)
    output: dataset file 

    '''
    with NpyAppendArray(signal_file) as npaa1:
        npaa1.append(signal_dataset)
    with NpyAppendArray(label_file) as npaa2:
        npaa2.append(label_dataset)

# %%
def ceildiv(a, b):
    '''
    Does ceiling division
    '''
    return -(a // -b)

# %% [markdown]
# ## Program Utama

# %% [markdown]
# Proses load dataset dan memilih data sesuai yang diinginkan

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.fftpack import dct

file_hdf5 = "D:/Download/merged/merge.hdf5"
header_file = "D:/Download/merged/merge.csv"

# reading the csv file into a dataframe:
df = pd.read_csv(header_file, engine='python')
print(f'total events in csv file: {len(df)}')

# filtering the dataframe with this condition 
df = df[(df.trace_category == 'earthquake_local') & (df.source_magnitude > 2.5)]
print(f'total events selected: {len(df)}')

# making a list of trace names for the selected data
list_event = df['trace_name'].to_list()
print(f'total events selected: {len(list_event)}')

# retrieving waveforms from the hdf5 file: 
dtfl = h5py.File(file_hdf5, 'r')
# Out:
# total events in csv file: 1265657
# total events selected: 150892
# total events selected: 150892

# %% [markdown]
# Proses setting window2 yang digunakan

# %%
#Access the attribute of period and total Samples
Period = 0.01
df = 1/Period
#First Calculation
train_windows_seconds = 1 #Try training window at ... seconds
train_windows_samples = int(train_windows_seconds / Period)
moving_windows_seconds = 0.04 #Try overlapping at ... second
moving_windows_samples = int(moving_windows_seconds/Period)

print("The period of this data is : ", Period, " Seconds")
print("Try the Training Windows for each ", train_windows_seconds, " Seconds")
print("So, the Training Windows for this data is for each ", train_windows_samples, " Samples")
print("Also, the Moving Windows for this data is for each ", moving_windows_samples, " Samples")
# Out:
# The period of this data is :  0.01  Seconds
# Try the Training Windows for each  1  Seconds
# So, the Training Windows for this data is for each  100  Samples
# Also, the Moving Windows for this data is for each  4  Samples

# %% [markdown]
# Proses memecah setiap sinyal menjadi beberapa window dan resampling (balancing)

# %%
# Calculate some important informations, mainly train_samples (number of training samples from this particular event)
Total_Samples = 6000 # 60s data with 100Hz freq
train_samples = int(1 + ((Total_Samples-train_windows_samples)/moving_windows_samples))
print(Total_Samples)
print(train_samples)
#counter for event
count = 0
#temp variable for
signal_dataset = np.zeros((train_samples*5, train_windows_samples,6))
print(signal_dataset.shape)
print(signal_dataset.nbytes)
#temp variable that is initiated after each balancing
label_dataset = np.zeros((train_samples*5), dtype = np.int32)
print(label_dataset.shape)
print(label_dataset.nbytes)
# Out:
# 6000
# 1476
# (7380, 100, 6)
# 35424000
# (7380,)
# 29520

# %% [markdown]
# Catatan penting: seharusnya save_iter kelipatan balance_iter

# %%
# Balance dataset after balance_iter number of events
balance_iter = 17
# Calculate some important informations, mainly train_samples (number of training samples from this particular event)
Total_Samples = 6000 # 60s data with 100Hz freq
train_samples = int(1 + ((Total_Samples-train_windows_samples)/moving_windows_samples)) 
# counters
count = 0 # event
countBalance = 0 # Balance
countSave = 0 # save
# temp variable for saving balance_iter number of events
temp_signal = np.zeros((train_samples*balance_iter, train_windows_samples,6))
# temp variable that is initiated after each balancing
#temp_label_2 = np.zeros((train_samples*balance_iter), dtype = np.int32)
temp_label_2 = np.zeros((1), dtype = np.int32)
# pointers
pointer_dataset = 0 #for undersampled dataset
pointer_signal = 0 #for temporary 'sliced' signals
# Define x and y equal to train_window_samples and moving_windows_samples
x = train_windows_samples 
y = moving_windows_samples

# dataset variables
#signal_dataset = np.zeros((train_samples*save_iter, train_windows_samples, 6)) # 3 time domain + 3 freq domain
#label_dataset = np.zeros((train_samples*save_iter), dtype = np.int32)
signal_dataset = np.zeros((1, train_windows_samples, 6)) # 3 time domain + 3 freq domain
label_dataset = np.zeros((1), dtype = np.int32)
signal_file = ("D:/S3_project/S Picker/Cooked_Dataset/Dataset100Hz/signal_dataset_M25_0.npy",
              "D:/S3_project/S Picker/Cooked_Dataset/Dataset100Hz/signal_dataset_M25_1.npy",
              "D:/S3_project/S Picker/Cooked_Dataset/Dataset100Hz/signal_dataset_M25_2.npy",
              "D:/S3_project/S Picker/Cooked_Dataset/Dataset100Hz/signal_dataset_M25_3.npy",
              "D:/S3_project/S Picker/Cooked_Dataset/Dataset100Hz/signal_dataset_M25_4.npy",
              "D:/S3_project/S Picker/Cooked_Dataset/Dataset100Hz/signal_dataset_M25_5.npy",
              "D:/S3_project/S Picker/Cooked_Dataset/Dataset100Hz/signal_dataset_M25_6.npy",
              "D:/S3_project/S Picker/Cooked_Dataset/Dataset100Hz/signal_dataset_M25_7.npy",
              "D:/S3_project/S Picker/Cooked_Dataset/Dataset100Hz/signal_dataset_M25_8.npy",
              "D:/S3_project/S Picker/Cooked_Dataset/Dataset100Hz/signal_dataset_M25_9.npy",
              "D:/S3_project/S Picker/Cooked_Dataset/Dataset100Hz/signal_dataset_M25_10.npy",
              "D:/S3_project/S Picker/Cooked_Dataset/Dataset100Hz/signal_dataset_M25_11.npy",
              "D:/S3_project/S Picker/Cooked_Dataset/Dataset100Hz/signal_dataset_M25_12.npy",
              "D:/S3_project/S Picker/Cooked_Dataset/Dataset100Hz/signal_dataset_M25_13.npy")
label_file = ("D:/S3_project/S Picker/Cooked_Dataset/Dataset100Hz/label_dataset_M25_0.npy",
             "D:/S3_project/S Picker/Cooked_Dataset/Dataset100Hz/label_dataset_M25_1.npy",
             "D:/S3_project/S Picker/Cooked_Dataset/Dataset100Hz/label_dataset_M25_2.npy",
             "D:/S3_project/S Picker/Cooked_Dataset/Dataset100Hz/label_dataset_M25_3.npy",
             "D:/S3_project/S Picker/Cooked_Dataset/Dataset100Hz/label_dataset_M25_4.npy",
             "D:/S3_project/S Picker/Cooked_Dataset/Dataset100Hz/label_dataset_M25_5.npy",
             "D:/S3_project/S Picker/Cooked_Dataset/Dataset100Hz/label_dataset_M25_6.npy",
             "D:/S3_project/S Picker/Cooked_Dataset/Dataset100Hz/label_dataset_M25_7.npy",
             "D:/S3_project/S Picker/Cooked_Dataset/Dataset100Hz/label_dataset_M25_8.npy",
             "D:/S3_project/S Picker/Cooked_Dataset/Dataset100Hz/label_dataset_M25_9.npy",
             "D:/S3_project/S Picker/Cooked_Dataset/Dataset100Hz/label_dataset_M25_10.npy",
             "D:/S3_project/S Picker/Cooked_Dataset/Dataset100Hz/label_dataset_M25_11.npy",
             "D:/S3_project/S Picker/Cooked_Dataset/Dataset100Hz/label_dataset_M25_12.npy",
             "D:/S3_project/S Picker/Cooked_Dataset/Dataset100Hz/label_dataset_M25_13.npy")

file_num = len(signal_file)
data_per_file = (len(list_event)//file_num)
save_iter = 68

print("Init!")

# Loop for every event in list_event
for counter, event in enumerate(list_event):
    # update counters
    count = count + 1
#     print(count, ". There will be ", train_samples, " Training samples from this traces")
    countBalance = countBalance + 1
    countSave = countSave + 1
    
#     current_time = time.time()
    
    dataset = dtfl.get('data/'+str(event)) 
    # convering hdf5 dataset into obspy sream
    st = make_stream(dataset)
    
    # fetch the traces from stream and filter it
    [dataE,dataN,dataZ,trZ] = FetchingAndFiltering(st)
    
    # checking elapsed time
#     print(f'fetchAndFilter: {time.time()-current_time}')
#     current_time = time.time()
    
    # LABELING with zero for initiation 
    temp_label = np.zeros((int(Total_Samples)), dtype = np.int32)
    
    # Pick the Arrival of P based on IRIS (on 60th second)
    a = int(dataset.attrs["s_arrival_sample"])
    # Indicate it with 1
    temp_label[a] = 1

    # Labeling Process and ADDING FREQ. DOMAIN info
    temp_label_2 = Labeling(train_samples, x, y, temp_label, temp_label_2)
    
    # Checking elapsed time
#     print(f'Labeling: {time.time()-current_time}')
#     current_time = time.time()
    
    # Inserting data to temporary dataset
    temp_signal = Appending(train_samples, dataE, dataN, dataZ, x , y, temp_signal, pointer_signal)
    
    # Checking elapsed time
#     print(f'Appending: {time.time()-current_time}')
    
    # Balancing Process
    # Balancing dataset after balance_iter data fetched
    if((countBalance == balance_iter) or (count == len(list_event))):
        temp_label_2 = np.delete(temp_label_2, 0, 0) #erasing first row because it is only placeholder for temp_label_2 before appending
        [signal_dataset, label_dataset] = Balancing(temp_signal,temp_label_2, signal_dataset, label_dataset)
        
        temp_label_2 = np.zeros((1), dtype = np.int32)
                
        # update counter and pointer
        countBalance = 0
        pointer_signal = 0
        
    # Saving process
    if ((countSave == save_iter) or (count == len(list_event))):
        print(f'Saving to file... count: {count}')
        SaveToFile(signal_dataset, label_dataset, signal_file[count//data_per_file], label_file[count//data_per_file])
        
        # start again
        signal_dataset = np.zeros((1, train_windows_samples, 6)) # 3 time domain + 3 freq domain
        label_dataset = np.zeros((1), dtype = np.int32)
        
        countSave = 0
    
    # update pointers
    if (countBalance != 0):
        pointer_signal = pointer_signal + train_samples 
    #pointer_dataset = pointer_dataset + pointer_dataset_inc
    
print(signal_dataset.shape)
print(label_dataset.shape)
# Out:
# Init!
# Saving to file... count: 68
# Saving to file... count: 136
# Saving to file... count: 204
# Saving to file... count: 272
# Saving to file... count: 340
# Saving to file... count: 408
# Saving to file... count: 476
# Saving to file... count: 544
# Saving to file... count: 612
# Saving to file... count: 680
# Saving to file... count: 748
# Saving to file... count: 816
# Saving to file... count: 884
# Saving to file... count: 952
# Saving to file... count: 1020
# Saving to file... count: 1088
# Saving to file... count: 1156
# Saving to file... count: 1224
# Saving to file... count: 1292
# Saving to file... count: 1360
# Saving to file... count: 1428
# Saving to file... count: 1496
# Saving to file... count: 1564
# Saving to file... count: 1632
# Saving to file... count: 1700
# Saving to file... count: 1768
# Saving to file... count: 1836
# Saving to file... count: 1904
# Saving to file... count: 1972
# Saving to file... count: 2040
# Saving to file... count: 2108
# Saving to file... count: 2176
# Saving to file... count: 2244
# Saving to file... count: 2312
# Saving to file... count: 2380
# Saving to file... count: 2448
# Saving to file... count: 2516
# Saving to file... count: 2584
# Saving to file... count: 2652
# Saving to file... count: 2720
# Saving to file... count: 2788
# Saving to file... count: 2856
# Saving to file... count: 2924
# Saving to file... count: 2992
# Saving to file... count: 3060
# Saving to file... count: 3128
# Saving to file... count: 3196
# Saving to file... count: 3264
# Saving to file... count: 3332
# Saving to file... count: 3400
# Saving to file... count: 3468
# Saving to file... count: 3536
# Saving to file... count: 3604
# Saving to file... count: 3672
# Saving to file... count: 3740
# Saving to file... count: 3808
# Saving to file... count: 3876
# Saving to file... count: 3944
# Saving to file... count: 4012
# Saving to file... count: 4080
# Saving to file... count: 4148
# Saving to file... count: 4216
# Saving to file... count: 4284
# Saving to file... count: 4352
# Saving to file... count: 4420
# Saving to file... count: 4488
# Saving to file... count: 4556
# Saving to file... count: 4624
# Saving to file... count: 4692
# Saving to file... count: 4760
# Saving to file... count: 4828
# Saving to file... count: 4896
# Saving to file... count: 4964
# Saving to file... count: 5032
# Saving to file... count: 5100
# Saving to file... count: 5168
# Saving to file... count: 5236
# Saving to file... count: 5304
# Saving to file... count: 5372
# Saving to file... count: 5440
# Saving to file... count: 5508
# Saving to file... count: 5576
# Saving to file... count: 5644
# Saving to file... count: 5712
# Saving to file... count: 5780
# Saving to file... count: 5848
# Saving to file... count: 5916
# Saving to file... count: 5984
# Saving to file... count: 6052
# Saving to file... count: 6120
# Saving to file... count: 6188
# Saving to file... count: 6256
# Saving to file... count: 6324
# Saving to file... count: 6392
# Saving to file... count: 6460
# Saving to file... count: 6528
# Saving to file... count: 6596
# Saving to file... count: 6664
# Saving to file... count: 6732
# Saving to file... count: 6800
# Saving to file... count: 6868
# Saving to file... count: 6936
# Saving to file... count: 7004
# Saving to file... count: 7072
# Saving to file... count: 7140
# Saving to file... count: 7208
# Saving to file... count: 7276
# Saving to file... count: 7344
# Saving to file... count: 7412
# Saving to file... count: 7480
# Saving to file... count: 7548
# Saving to file... count: 7616
# Saving to file... count: 7684
# Saving to file... count: 7752
# Saving to file... count: 7820
# Saving to file... count: 7888
# Saving to file... count: 7956
# Saving to file... count: 8024
# Saving to file... count: 8092
# Saving to file... count: 8160
# Saving to file... count: 8228
# Saving to file... count: 8296
# Saving to file... count: 8364
# Saving to file... count: 8432
# Saving to file... count: 8500
# Saving to file... count: 8568
# Saving to file... count: 8636
# Saving to file... count: 8704
# Saving to file... count: 8772
# Saving to file... count: 8840
# Saving to file... count: 8908
# Saving to file... count: 8976
# Saving to file... count: 9044
# Saving to file... count: 9112
# Saving to file... count: 9180
# Saving to file... count: 9248
# Saving to file... count: 9316
# Saving to file... count: 9384
# Saving to file... count: 9452
# Saving to file... count: 9520
# Saving to file... count: 9588
# Saving to file... count: 9656
# Saving to file... count: 9724
# Saving to file... count: 9792
# Saving to file... count: 9860
# Saving to file... count: 9928
# Saving to file... count: 9996
# Saving to file... count: 10064
# Saving to file... count: 10132
# Saving to file... count: 10200
# Saving to file... count: 10268
# Saving to file... count: 10336
# Saving to file... count: 10404
# Saving to file... count: 10472
# Saving to file... count: 10540
# Saving to file... count: 10608
# Saving to file... count: 10676
# Saving to file... count: 10744
# Saving to file... count: 10812
# Saving to file... count: 10880
# Saving to file... count: 10948
# Saving to file... count: 11016
# Saving to file... count: 11084
# Saving to file... count: 11152
# Saving to file... count: 11220
# Saving to file... count: 11288
# Saving to file... count: 11356
# Saving to file... count: 11424
# Saving to file... count: 11492
# Saving to file... count: 11560
# Saving to file... count: 11628
# Saving to file... count: 11696
# Saving to file... count: 11764
# Saving to file... count: 11832
# Saving to file... count: 11900
# Saving to file... count: 11968
# Saving to file... count: 12036
# Saving to file... count: 12104
# Saving to file... count: 12172
# Saving to file... count: 12240
# Saving to file... count: 12308
# Saving to file... count: 12376
# Saving to file... count: 12444
# Saving to file... count: 12512
# Saving to file... count: 12580
# Saving to file... count: 12648
# Saving to file... count: 12716
# Saving to file... count: 12784
# Saving to file... count: 12852
# Saving to file... count: 12920
# Saving to file... count: 12988
# Saving to file... count: 13056
# Saving to file... count: 13124
# Saving to file... count: 13192
# Saving to file... count: 13260
# Saving to file... count: 13328
# Saving to file... count: 13396
# Saving to file... count: 13464
# Saving to file... count: 13532
# Saving to file... count: 13600
# Saving to file... count: 13668
# Saving to file... count: 13736
# Saving to file... count: 13804
# Saving to file... count: 13872
# Saving to file... count: 13940
# Saving to file... count: 14008
# Saving to file... count: 14076
# Saving to file... count: 14144
# Saving to file... count: 14212
# Saving to file... count: 14280
# Saving to file... count: 14348
# Saving to file... count: 14416
# Saving to file... count: 14484
# Saving to file... count: 14552
# Saving to file... count: 14620
# Saving to file... count: 14688
# Saving to file... count: 14756
# Saving to file... count: 14824
# Saving to file... count: 14892
# Saving to file... count: 14960
# Saving to file... count: 15028
# Saving to file... count: 15096
# Saving to file... count: 15164
# Saving to file... count: 15232
# Saving to file... count: 15300
# Saving to file... count: 15368
# Saving to file... count: 15436
# Saving to file... count: 15504
# Saving to file... count: 15572
# Saving to file... count: 15640
# Saving to file... count: 15708
# Saving to file... count: 15776
# Saving to file... count: 15844
# Saving to file... count: 15912
# Saving to file... count: 15980
# Saving to file... count: 16048
# Saving to file... count: 16116
# Saving to file... count: 16184
# Saving to file... count: 16252
# Saving to file... count: 16320
# Saving to file... count: 16388
# Saving to file... count: 16456
# Saving to file... count: 16524
# Saving to file... count: 16592
# Saving to file... count: 16660
# Saving to file... count: 16728
# Saving to file... count: 16796
# Saving to file... count: 16864
# Saving to file... count: 16932
# Saving to file... count: 17000
# Saving to file... count: 17068
# Saving to file... count: 17136
# Saving to file... count: 17204
# Saving to file... count: 17272
# Saving to file... count: 17340
# Saving to file... count: 17408
# Saving to file... count: 17476
# Saving to file... count: 17544
# Saving to file... count: 17612
# Saving to file... count: 17680
# Saving to file... count: 17748
# Saving to file... count: 17816
# Saving to file... count: 17884
# Saving to file... count: 17952
# Saving to file... count: 18020
# Saving to file... count: 18088
# Saving to file... count: 18156
# Saving to file... count: 18224
# Saving to file... count: 18292
# Saving to file... count: 18360
# Saving to file... count: 18428
# Saving to file... count: 18496
# Saving to file... count: 18564
# Saving to file... count: 18632
# Saving to file... count: 18700
# Saving to file... count: 18768
# Saving to file... count: 18836
# Saving to file... count: 18904
# Saving to file... count: 18972
# Saving to file... count: 19040
# Saving to file... count: 19108
# Saving to file... count: 19176
# Saving to file... count: 19244
# Saving to file... count: 19312
# Saving to file... count: 19380
# Saving to file... count: 19448
# Saving to file... count: 19516
# Saving to file... count: 19584
# Saving to file... count: 19652
# Saving to file... count: 19720
# Saving to file... count: 19788
# Saving to file... count: 19856
# Saving to file... count: 19924
# Saving to file... count: 19992
# Saving to file... count: 20060
# Saving to file... count: 20128
# Saving to file... count: 20196
# Saving to file... count: 20264
# Saving to file... count: 20332
# Saving to file... count: 20400
# Saving to file... count: 20468
# Saving to file... count: 20536
# Saving to file... count: 20604
# Saving to file... count: 20672
# Saving to file... count: 20740
# Saving to file... count: 20808
# Saving to file... count: 20876
# Saving to file... count: 20944
# Saving to file... count: 21012
# Saving to file... count: 21080
# Saving to file... count: 21148
# Saving to file... count: 21216
# Saving to file... count: 21284
# Saving to file... count: 21352
# Saving to file... count: 21420
# Saving to file... count: 21488
# Saving to file... count: 21556
# Saving to file... count: 21624
# Saving to file... count: 21692
# Saving to file... count: 21760
# Saving to file... count: 21828
# Saving to file... count: 21896
# Saving to file... count: 21964
# Saving to file... count: 22032
# Saving to file... count: 22100
# Saving to file... count: 22168
# Saving to file... count: 22236
# Saving to file... count: 22304
# Saving to file... count: 22372
# Saving to file... count: 22440
# Saving to file... count: 22508
# Saving to file... count: 22576
# Saving to file... count: 22644
# Saving to file... count: 22712
# Saving to file... count: 22780
# Saving to file... count: 22848
# Saving to file... count: 22916
# Saving to file... count: 22984
# Saving to file... count: 23052
# Saving to file... count: 23120
# Saving to file... count: 23188
# Saving to file... count: 23256
# Saving to file... count: 23324
# Saving to file... count: 23392
# Saving to file... count: 23460
# Saving to file... count: 23528
# Saving to file... count: 23596
# Saving to file... count: 23664
# Saving to file... count: 23732
# Saving to file... count: 23800
# Saving to file... count: 23868
# Saving to file... count: 23936
# Saving to file... count: 24004
# Saving to file... count: 24072
# Saving to file... count: 24140
# Saving to file... count: 24208
# Saving to file... count: 24276
# Saving to file... count: 24344
# Saving to file... count: 24412
# Saving to file... count: 24480
# Saving to file... count: 24548
# Saving to file... count: 24616
# Saving to file... count: 24684
# Saving to file... count: 24752
# Saving to file... count: 24820
# Saving to file... count: 24888
# Saving to file... count: 24956
# Saving to file... count: 25024
# Saving to file... count: 25092
# Saving to file... count: 25160
# Saving to file... count: 25228
# Saving to file... count: 25296
# Saving to file... count: 25364
# Saving to file... count: 25432
# Saving to file... count: 25500
# Saving to file... count: 25568
# Saving to file... count: 25636
# Saving to file... count: 25704
# Saving to file... count: 25772
# Saving to file... count: 25840
# Saving to file... count: 25908
# Saving to file... count: 25976
# Saving to file... count: 26044
# Saving to file... count: 26112
# Saving to file... count: 26180
# Saving to file... count: 26248
# Saving to file... count: 26316
# Saving to file... count: 26384
# Saving to file... count: 26452
# Saving to file... count: 26520
# Saving to file... count: 26588
# Saving to file... count: 26656
# Saving to file... count: 26724
# Saving to file... count: 26792
# Saving to file... count: 26860
# Saving to file... count: 26928
# Saving to file... count: 26996
# Saving to file... count: 27064
# Saving to file... count: 27132
# Saving to file... count: 27200
# Saving to file... count: 27268
# Saving to file... count: 27336
# Saving to file... count: 27404
# Saving to file... count: 27472
# Saving to file... count: 27540
# Saving to file... count: 27608
# Saving to file... count: 27676
# Saving to file... count: 27744
# Saving to file... count: 27812
# Saving to file... count: 27880
# Saving to file... count: 27948
# Saving to file... count: 28016
# Saving to file... count: 28084
# Saving to file... count: 28152
# Saving to file... count: 28220
# Saving to file... count: 28288
# Saving to file... count: 28356
# Saving to file... count: 28424
# Saving to file... count: 28492
# Saving to file... count: 28560
# Saving to file... count: 28628
# Saving to file... count: 28696
# Saving to file... count: 28764
# Saving to file... count: 28832
# Saving to file... count: 28900
# Saving to file... count: 28968
# Saving to file... count: 29036
# Saving to file... count: 29104
# Saving to file... count: 29172
# Saving to file... count: 29240
# Saving to file... count: 29308
# Saving to file... count: 29376
# Saving to file... count: 29444
# Saving to file... count: 29512
# Saving to file... count: 29580
# Saving to file... count: 29648
# Saving to file... count: 29716
# Saving to file... count: 29784
# Saving to file... count: 29852
# Saving to file... count: 29920
# Saving to file... count: 29988
# Saving to file... count: 30056
# Saving to file... count: 30124
# Saving to file... count: 30192
# Saving to file... count: 30260
# Saving to file... count: 30328
# Saving to file... count: 30396
# Saving to file... count: 30464
# Saving to file... count: 30532
# Saving to file... count: 30600
# Saving to file... count: 30668
# Saving to file... count: 30736
# Saving to file... count: 30804
# Saving to file... count: 30872
# Saving to file... count: 30940
# Saving to file... count: 31008
# Saving to file... count: 31076
# Saving to file... count: 31144
# Saving to file... count: 31212
# Saving to file... count: 31280
# Saving to file... count: 31348
# Saving to file... count: 31416
# Saving to file... count: 31484
# Saving to file... count: 31552
# Saving to file... count: 31620
# Saving to file... count: 31688
# Saving to file... count: 31756
# Saving to file... count: 31824
# Saving to file... count: 31892
# Saving to file... count: 31960
# Saving to file... count: 32028
# Saving to file... count: 32096
# Saving to file... count: 32164
# Saving to file... count: 32232
# Saving to file... count: 32300
# Saving to file... count: 32368
# Saving to file... count: 32436
# Saving to file... count: 32504
# Saving to file... count: 32572
# Saving to file... count: 32640
# Saving to file... count: 32708
# Saving to file... count: 32776
# Saving to file... count: 32844
# Saving to file... count: 32912
# Saving to file... count: 32980
# Saving to file... count: 33048
# Saving to file... count: 33116
# Saving to file... count: 33184
# Saving to file... count: 33252
# Saving to file... count: 33320
# Saving to file... count: 33388
# Saving to file... count: 33456
# Saving to file... count: 33524
# Saving to file... count: 33592
# Saving to file... count: 33660
# Saving to file... count: 33728
# Saving to file... count: 33796
# Saving to file... count: 33864
# Saving to file... count: 33932
# Saving to file... count: 34000
# Saving to file... count: 34068
# Saving to file... count: 34136
# Saving to file... count: 34204
# Saving to file... count: 34272
# Saving to file... count: 34340
# Saving to file... count: 34408
# Saving to file... count: 34476
# Saving to file... count: 34544
# Saving to file... count: 34612
# Saving to file... count: 34680
# Saving to file... count: 34748
# Saving to file... count: 34816
# Saving to file... count: 34884
# Saving to file... count: 34952
# Saving to file... count: 35020
# Saving to file... count: 35088
# Saving to file... count: 35156
# Saving to file... count: 35224
# Saving to file... count: 35292
# Saving to file... count: 35360
# Saving to file... count: 35428
# Saving to file... count: 35496
# Saving to file... count: 35564
# Saving to file... count: 35632
# Saving to file... count: 35700
# Saving to file... count: 35768
# Saving to file... count: 35836
# Saving to file... count: 35904
# Saving to file... count: 35972
# Saving to file... count: 36040
# Saving to file... count: 36108
# Saving to file... count: 36176
# Saving to file... count: 36244
# Saving to file... count: 36312
# Saving to file... count: 36380
# Saving to file... count: 36448
# Saving to file... count: 36516
# Saving to file... count: 36584
# Saving to file... count: 36652
# Saving to file... count: 36720
# Saving to file... count: 36788
# Saving to file... count: 36856
# Saving to file... count: 36924
# Saving to file... count: 36992
# Saving to file... count: 37060
# Saving to file... count: 37128
# Saving to file... count: 37196
# Saving to file... count: 37264
# Saving to file... count: 37332
# Saving to file... count: 37400
# Saving to file... count: 37468
# Saving to file... count: 37536
# Saving to file... count: 37604
# Saving to file... count: 37672
# Saving to file... count: 37740
# Saving to file... count: 37808
# Saving to file... count: 37876
# Saving to file... count: 37944
# Saving to file... count: 38012
# Saving to file... count: 38080
# Saving to file... count: 38148
# Saving to file... count: 38216
# Saving to file... count: 38284
# Saving to file... count: 38352
# Saving to file... count: 38420
# Saving to file... count: 38488
# Saving to file... count: 38556
# Saving to file... count: 38624
# Saving to file... count: 38692
# Saving to file... count: 38760
# Saving to file... count: 38828
# Saving to file... count: 38896
# Saving to file... count: 38964
# Saving to file... count: 39032
# Saving to file... count: 39100
# Saving to file... count: 39168
# Saving to file... count: 39236
# Saving to file... count: 39304
# Saving to file... count: 39372
# Saving to file... count: 39440
# Saving to file... count: 39508
# Saving to file... count: 39576
# Saving to file... count: 39644
# Saving to file... count: 39712
# Saving to file... count: 39780
# Saving to file... count: 39848
# Saving to file... count: 39916
# Saving to file... count: 39984
# Saving to file... count: 40052
# Saving to file... count: 40120
# Saving to file... count: 40188
# Saving to file... count: 40256
# Saving to file... count: 40324
# Saving to file... count: 40392
# Saving to file... count: 40460
# Saving to file... count: 40528
# Saving to file... count: 40596
# Saving to file... count: 40664
# Saving to file... count: 40732
# Saving to file... count: 40800
# Saving to file... count: 40868
# Saving to file... count: 40936
# Saving to file... count: 41004
# Saving to file... count: 41072
# Saving to file... count: 41140
# Saving to file... count: 41208
# Saving to file... count: 41276
# Saving to file... count: 41344
# Saving to file... count: 41412
# Saving to file... count: 41480
# Saving to file... count: 41548
# Saving to file... count: 41616
# Saving to file... count: 41684
# Saving to file... count: 41752
# Saving to file... count: 41820
# Saving to file... count: 41888
# Saving to file... count: 41956
# Saving to file... count: 42024
# Saving to file... count: 42092
# Saving to file... count: 42160
# Saving to file... count: 42228
# Saving to file... count: 42296
# Saving to file... count: 42364
# Saving to file... count: 42432
# Saving to file... count: 42500
# Saving to file... count: 42568
# Saving to file... count: 42636
# Saving to file... count: 42704
# Saving to file... count: 42772
# Saving to file... count: 42840
# Saving to file... count: 42908
# Saving to file... count: 42976
# Saving to file... count: 43044
# Saving to file... count: 43112
# Saving to file... count: 43180
# Saving to file... count: 43248
# Saving to file... count: 43316
# Saving to file... count: 43384
# Saving to file... count: 43452
# Saving to file... count: 43520
# Saving to file... count: 43588
# Saving to file... count: 43656
# Saving to file... count: 43724
# Saving to file... count: 43792
# Saving to file... count: 43860
# Saving to file... count: 43928
# Saving to file... count: 43996
# Saving to file... count: 44064
# Saving to file... count: 44132
# Saving to file... count: 44200
# Saving to file... count: 44268
# Saving to file... count: 44336
# Saving to file... count: 44404
# Saving to file... count: 44472
# Saving to file... count: 44540
# Saving to file... count: 44608
# Saving to file... count: 44676
# Saving to file... count: 44744
# Saving to file... count: 44812
# Saving to file... count: 44880
# Saving to file... count: 44948
# Saving to file... count: 45016
# Saving to file... count: 45084
# Saving to file... count: 45152
# Saving to file... count: 45220
# Saving to file... count: 45288
# Saving to file... count: 45356
# Saving to file... count: 45424
# Saving to file... count: 45492
# Saving to file... count: 45560
# Saving to file... count: 45628
# Saving to file... count: 45696
# Saving to file... count: 45764
# Saving to file... count: 45832
# Saving to file... count: 45900
# Saving to file... count: 45968
# Saving to file... count: 46036
# Saving to file... count: 46104
# Saving to file... count: 46172
# Saving to file... count: 46240
# Saving to file... count: 46308
# Saving to file... count: 46376
# Saving to file... count: 46444
# Saving to file... count: 46512
# Saving to file... count: 46580
# Saving to file... count: 46648
# Saving to file... count: 46716
# Saving to file... count: 46784
# Saving to file... count: 46852
# Saving to file... count: 46920
# Saving to file... count: 46988
# Saving to file... count: 47056
# Saving to file... count: 47124
# Saving to file... count: 47192
# Saving to file... count: 47260
# Saving to file... count: 47328
# Saving to file... count: 47396
# Saving to file... count: 47464
# Saving to file... count: 47532
# Saving to file... count: 47600
# Saving to file... count: 47668
# Saving to file... count: 47736
# Saving to file... count: 47804
# Saving to file... count: 47872
# Saving to file... count: 47940
# Saving to file... count: 48008
# Saving to file... count: 48076
# Saving to file... count: 48144
# Saving to file... count: 48212
# Saving to file... count: 48280
# Saving to file... count: 48348
# Saving to file... count: 48416
# Saving to file... count: 48484
# Saving to file... count: 48552
# Saving to file... count: 48620
# Saving to file... count: 48688
# Saving to file... count: 48756
# Saving to file... count: 48824
# Saving to file... count: 48892
# Saving to file... count: 48960
# Saving to file... count: 49028
# Saving to file... count: 49096
# Saving to file... count: 49164
# Saving to file... count: 49232
# Saving to file... count: 49300
# Saving to file... count: 49368
# Saving to file... count: 49436
# Saving to file... count: 49504
# Saving to file... count: 49572
# Saving to file... count: 49640
# Saving to file... count: 49708
# Saving to file... count: 49776
# Saving to file... count: 49844
# Saving to file... count: 49912
# Saving to file... count: 49980
# Saving to file... count: 50048
# Saving to file... count: 50116
# Saving to file... count: 50184
# Saving to file... count: 50252
# Saving to file... count: 50320
# Saving to file... count: 50388
# Saving to file... count: 50456
# Saving to file... count: 50524
# Saving to file... count: 50592
# Saving to file... count: 50660
# Saving to file... count: 50728
# Saving to file... count: 50796
# Saving to file... count: 50864
# Saving to file... count: 50932
# Saving to file... count: 51000
# Saving to file... count: 51068
# Saving to file... count: 51136
# Saving to file... count: 51204
# Saving to file... count: 51272
# Saving to file... count: 51340
# Saving to file... count: 51408
# Saving to file... count: 51476
# Saving to file... count: 51544
# Saving to file... count: 51612
# Saving to file... count: 51680
# Saving to file... count: 51748
# Saving to file... count: 51816
# Saving to file... count: 51884
# Saving to file... count: 51952
# Saving to file... count: 52020
# Saving to file... count: 52088
# Saving to file... count: 52156
# Saving to file... count: 52224
# Saving to file... count: 52292
# Saving to file... count: 52360
# Saving to file... count: 52428
# Saving to file... count: 52496
# Saving to file... count: 52564
# Saving to file... count: 52632
# Saving to file... count: 52700
# Saving to file... count: 52768
# Saving to file... count: 52836
# Saving to file... count: 52904
# Saving to file... count: 52972
# Saving to file... count: 53040
# Saving to file... count: 53108
# Saving to file... count: 53176
# Saving to file... count: 53244
# Saving to file... count: 53312
# Saving to file... count: 53380
# Saving to file... count: 53448
# Saving to file... count: 53516
# Saving to file... count: 53584
# Saving to file... count: 53652
# Saving to file... count: 53720
# Saving to file... count: 53788
# Saving to file... count: 53856
# Saving to file... count: 53924
# Saving to file... count: 53992
# Saving to file... count: 54060
# Saving to file... count: 54128
# Saving to file... count: 54196
# Saving to file... count: 54264
# Saving to file... count: 54332
# Saving to file... count: 54400
# Saving to file... count: 54468
# Saving to file... count: 54536
# Saving to file... count: 54604
# Saving to file... count: 54672
# Saving to file... count: 54740
# Saving to file... count: 54808
# Saving to file... count: 54876
# Saving to file... count: 54944
# Saving to file... count: 55012
# Saving to file... count: 55080
# Saving to file... count: 55148
# Saving to file... count: 55216
# Saving to file... count: 55284
# Saving to file... count: 55352
# Saving to file... count: 55420
# Saving to file... count: 55488
# Saving to file... count: 55556
# Saving to file... count: 55624
# Saving to file... count: 55692
# Saving to file... count: 55760
# Saving to file... count: 55828
# Saving to file... count: 55896
# Saving to file... count: 55964
# Saving to file... count: 56032
# Saving to file... count: 56100
# Saving to file... count: 56168
# Saving to file... count: 56236
# Saving to file... count: 56304
# Saving to file... count: 56372
# Saving to file... count: 56440
# Saving to file... count: 56508
# Saving to file... count: 56576
# Saving to file... count: 56644
# Saving to file... count: 56712
# Saving to file... count: 56780
# Saving to file... count: 56848
# Saving to file... count: 56916
# Saving to file... count: 56984
# Saving to file... count: 57052
# Saving to file... count: 57120
# Saving to file... count: 57188
# Saving to file... count: 57256
# Saving to file... count: 57324
# Saving to file... count: 57392
# Saving to file... count: 57460
# Saving to file... count: 57528
# Saving to file... count: 57596
# Saving to file... count: 57664
# Saving to file... count: 57732
# Saving to file... count: 57800
# Saving to file... count: 57868
# Saving to file... count: 57936
# Saving to file... count: 58004
# Saving to file... count: 58072
# Saving to file... count: 58140
# Saving to file... count: 58208
# Saving to file... count: 58276
# Saving to file... count: 58344
# Saving to file... count: 58412
# Saving to file... count: 58480
# Saving to file... count: 58548
# Saving to file... count: 58616
# Saving to file... count: 58684
# Saving to file... count: 58752
# Saving to file... count: 58820
# Saving to file... count: 58888
# Saving to file... count: 58956
# Saving to file... count: 59024
# Saving to file... count: 59092
# Saving to file... count: 59160
# Saving to file... count: 59228
# Saving to file... count: 59296
# Saving to file... count: 59364
# Saving to file... count: 59432
# Saving to file... count: 59500
# Saving to file... count: 59568
# Saving to file... count: 59636
# Saving to file... count: 59704
# Saving to file... count: 59772
# Saving to file... count: 59840
# Saving to file... count: 59908
# Saving to file... count: 59976
# Saving to file... count: 60044
# Saving to file... count: 60112
# Saving to file... count: 60180
# Saving to file... count: 60248
# Saving to file... count: 60316
# Saving to file... count: 60384
# Saving to file... count: 60452
# Saving to file... count: 60520
# Saving to file... count: 60588
# Saving to file... count: 60656
# Saving to file... count: 60724
# Saving to file... count: 60792
# Saving to file... count: 60860
# Saving to file... count: 60928
# Saving to file... count: 60996
# Saving to file... count: 61064
# Saving to file... count: 61132
# Saving to file... count: 61200
# Saving to file... count: 61268
# Saving to file... count: 61336
# Saving to file... count: 61404
# Saving to file... count: 61472
# Saving to file... count: 61540
# Saving to file... count: 61608
# Saving to file... count: 61676
# Saving to file... count: 61744
# Saving to file... count: 61812
# Saving to file... count: 61880
# Saving to file... count: 61948
# Saving to file... count: 62016
# Saving to file... count: 62084
# Saving to file... count: 62152
# Saving to file... count: 62220
# Saving to file... count: 62288
# Saving to file... count: 62356
# Saving to file... count: 62424
# Saving to file... count: 62492
# Saving to file... count: 62560
# Saving to file... count: 62628
# Saving to file... count: 62696
# Saving to file... count: 62764
# Saving to file... count: 62832
# Saving to file... count: 62900
# Saving to file... count: 62968
# Saving to file... count: 63036
# Saving to file... count: 63104
# Saving to file... count: 63172
# Saving to file... count: 63240
# Saving to file... count: 63308
# Saving to file... count: 63376
# Saving to file... count: 63444
# Saving to file... count: 63512
# Saving to file... count: 63580
# Saving to file... count: 63648
# Saving to file... count: 63716
# Saving to file... count: 63784
# Saving to file... count: 63852
# Saving to file... count: 63920
# Saving to file... count: 63988
# Saving to file... count: 64056
# Saving to file... count: 64124
# Saving to file... count: 64192
# Saving to file... count: 64260
# Saving to file... count: 64328
# Saving to file... count: 64396
# Saving to file... count: 64464
# Saving to file... count: 64532
# Saving to file... count: 64600
# Saving to file... count: 64668
# Saving to file... count: 64736
# Saving to file... count: 64804
# Saving to file... count: 64872
# Saving to file... count: 64940
# Saving to file... count: 65008
# Saving to file... count: 65076
# Saving to file... count: 65144
# Saving to file... count: 65212
# Saving to file... count: 65280
# Saving to file... count: 65348
# Saving to file... count: 65416
# Saving to file... count: 65484
# Saving to file... count: 65552
# Saving to file... count: 65620
# Saving to file... count: 65688
# Saving to file... count: 65756
# Saving to file... count: 65824
# Saving to file... count: 65892
# Saving to file... count: 65960
# Saving to file... count: 66028
# Saving to file... count: 66096
# Saving to file... count: 66164
# Saving to file... count: 66232
# Saving to file... count: 66300
# Saving to file... count: 66368
# Saving to file... count: 66436
# Saving to file... count: 66504
# Saving to file... count: 66572
# Saving to file... count: 66640
# Saving to file... count: 66708
# Saving to file... count: 66776
# Saving to file... count: 66844
# Saving to file... count: 66912
# Saving to file... count: 66980
# Saving to file... count: 67048
# Saving to file... count: 67116
# Saving to file... count: 67184
# Saving to file... count: 67252
# Saving to file... count: 67320
# Saving to file... count: 67388
# Saving to file... count: 67456
# Saving to file... count: 67524
# Saving to file... count: 67592
# Saving to file... count: 67660
# Saving to file... count: 67728
# Saving to file... count: 67796
# Saving to file... count: 67864
# Saving to file... count: 67932
# Saving to file... count: 68000
# Saving to file... count: 68068
# Saving to file... count: 68136
# Saving to file... count: 68204
# Saving to file... count: 68272
# Saving to file... count: 68340
# Saving to file... count: 68408
# Saving to file... count: 68476
# Saving to file... count: 68544
# Saving to file... count: 68612
# Saving to file... count: 68680
# Saving to file... count: 68748
# Saving to file... count: 68816
# Saving to file... count: 68884
# Saving to file... count: 68952
# Saving to file... count: 69020
# Saving to file... count: 69088
# Saving to file... count: 69156
# Saving to file... count: 69224
# Saving to file... count: 69292
# Saving to file... count: 69360
# Saving to file... count: 69428
# Saving to file... count: 69496
# Saving to file... count: 69564
# Saving to file... count: 69632
# Saving to file... count: 69700
# Saving to file... count: 69768
# Saving to file... count: 69836
# Saving to file... count: 69904
# Saving to file... count: 69972
# Saving to file... count: 70040
# Saving to file... count: 70108
# Saving to file... count: 70176
# Saving to file... count: 70244
# Saving to file... count: 70312
# Saving to file... count: 70380
# Saving to file... count: 70448
# Saving to file... count: 70516
# Saving to file... count: 70584
# Saving to file... count: 70652
# Saving to file... count: 70720
# Saving to file... count: 70788
# Saving to file... count: 70856
# Saving to file... count: 70924
# Saving to file... count: 70992
# Saving to file... count: 71060
# Saving to file... count: 71128
# Saving to file... count: 71196
# Saving to file... count: 71264
# Saving to file... count: 71332
# Saving to file... count: 71400
# Saving to file... count: 71468
# Saving to file... count: 71536
# Saving to file... count: 71604
# Saving to file... count: 71672
# Saving to file... count: 71740
# Saving to file... count: 71808
# Saving to file... count: 71876
# Saving to file... count: 71944
# Saving to file... count: 72012
# Saving to file... count: 72080
# Saving to file... count: 72148
# Saving to file... count: 72216
# Saving to file... count: 72284
# Saving to file... count: 72352
# Saving to file... count: 72420
# Saving to file... count: 72488
# Saving to file... count: 72556
# Saving to file... count: 72624
# Saving to file... count: 72692
# Saving to file... count: 72760
# Saving to file... count: 72828
# Saving to file... count: 72896
# Saving to file... count: 72964
# Saving to file... count: 73032
# Saving to file... count: 73100
# Saving to file... count: 73168
# Saving to file... count: 73236
# Saving to file... count: 73304
# Saving to file... count: 73372
# Saving to file... count: 73440
# Saving to file... count: 73508
# Saving to file... count: 73576
# Saving to file... count: 73644
# Saving to file... count: 73712
# Saving to file... count: 73780
# Saving to file... count: 73848
# Saving to file... count: 73916
# Saving to file... count: 73984
# Saving to file... count: 74052
# Saving to file... count: 74120
# Saving to file... count: 74188
# Saving to file... count: 74256
# Saving to file... count: 74324
# Saving to file... count: 74392
# Saving to file... count: 74460
# Saving to file... count: 74528
# Saving to file... count: 74596
# Saving to file... count: 74664
# Saving to file... count: 74732
# Saving to file... count: 74800
# Saving to file... count: 74868
# Saving to file... count: 74936
# Saving to file... count: 75004
# Saving to file... count: 75072
# Saving to file... count: 75140
# Saving to file... count: 75208
# Saving to file... count: 75276
# Saving to file... count: 75344
# Saving to file... count: 75412
# Saving to file... count: 75480
# Saving to file... count: 75548
# Saving to file... count: 75616
# Saving to file... count: 75684
# Saving to file... count: 75752
# Saving to file... count: 75820
# Saving to file... count: 75888
# Saving to file... count: 75956
# Saving to file... count: 76024
# Saving to file... count: 76092
# Saving to file... count: 76160
# Saving to file... count: 76228
# Saving to file... count: 76296
# Saving to file... count: 76364
# Saving to file... count: 76432
# Saving to file... count: 76500
# Saving to file... count: 76568
# Saving to file... count: 76636
# Saving to file... count: 76704
# Saving to file... count: 76772
# Saving to file... count: 76840
# Saving to file... count: 76908
# Saving to file... count: 76976
# Saving to file... count: 77044
# Saving to file... count: 77112
# Saving to file... count: 77180
# Saving to file... count: 77248
# Saving to file... count: 77316
# Saving to file... count: 77384
# Saving to file... count: 77452
# Saving to file... count: 77520
# Saving to file... count: 77588
# Saving to file... count: 77656
# Saving to file... count: 77724
# Saving to file... count: 77792
# Saving to file... count: 77860
# Saving to file... count: 77928
# Saving to file... count: 77996
# Saving to file... count: 78064
# Saving to file... count: 78132
# Saving to file... count: 78200
# Saving to file... count: 78268
# Saving to file... count: 78336
# Saving to file... count: 78404
# Saving to file... count: 78472
# Saving to file... count: 78540
# Saving to file... count: 78608
# Saving to file... count: 78676
# Saving to file... count: 78744
# Saving to file... count: 78812
# Saving to file... count: 78880
# Saving to file... count: 78948
# Saving to file... count: 79016
# Saving to file... count: 79084
# Saving to file... count: 79152
# Saving to file... count: 79220
# Saving to file... count: 79288
# Saving to file... count: 79356
# Saving to file... count: 79424
# Saving to file... count: 79492
# Saving to file... count: 79560
# Saving to file... count: 79628
# Saving to file... count: 79696
# Saving to file... count: 79764
# Saving to file... count: 79832
# Saving to file... count: 79900
# Saving to file... count: 79968
# Saving to file... count: 80036
# Saving to file... count: 80104
# Saving to file... count: 80172
# Saving to file... count: 80240
# Saving to file... count: 80308
# Saving to file... count: 80376
# Saving to file... count: 80444
# Saving to file... count: 80512
# Saving to file... count: 80580
# Saving to file... count: 80648
# Saving to file... count: 80716
# Saving to file... count: 80784
# Saving to file... count: 80852
# Saving to file... count: 80920
# Saving to file... count: 80988
# Saving to file... count: 81056
# Saving to file... count: 81124
# Saving to file... count: 81192
# Saving to file... count: 81260
# Saving to file... count: 81328
# Saving to file... count: 81396
# Saving to file... count: 81464
# Saving to file... count: 81532
# Saving to file... count: 81600
# Saving to file... count: 81668
# Saving to file... count: 81736
# Saving to file... count: 81804
# Saving to file... count: 81872
# Saving to file... count: 81940
# Saving to file... count: 82008
# Saving to file... count: 82076
# Saving to file... count: 82144
# Saving to file... count: 82212
# Saving to file... count: 82280
# Saving to file... count: 82348
# Saving to file... count: 82416
# Saving to file... count: 82484
# Saving to file... count: 82552
# Saving to file... count: 82620
# Saving to file... count: 82688
# Saving to file... count: 82756
# Saving to file... count: 82824
# Saving to file... count: 82892
# Saving to file... count: 82960
# Saving to file... count: 83028
# Saving to file... count: 83096
# Saving to file... count: 83164
# Saving to file... count: 83232
# Saving to file... count: 83300
# Saving to file... count: 83368
# Saving to file... count: 83436
# Saving to file... count: 83504
# Saving to file... count: 83572
# Saving to file... count: 83640
# Saving to file... count: 83708
# Saving to file... count: 83776
# Saving to file... count: 83844
# Saving to file... count: 83912
# Saving to file... count: 83980
# Saving to file... count: 84048
# Saving to file... count: 84116
# Saving to file... count: 84184
# Saving to file... count: 84252
# Saving to file... count: 84320
# Saving to file... count: 84388
# Saving to file... count: 84456
# Saving to file... count: 84524
# Saving to file... count: 84592
# Saving to file... count: 84660
# Saving to file... count: 84728
# Saving to file... count: 84796
# Saving to file... count: 84864
# Saving to file... count: 84932
# Saving to file... count: 85000
# Saving to file... count: 85068
# Saving to file... count: 85136
# Saving to file... count: 85204
# Saving to file... count: 85272
# Saving to file... count: 85340
# Saving to file... count: 85408
# Saving to file... count: 85476
# Saving to file... count: 85544
# Saving to file... count: 85612
# Saving to file... count: 85680
# Saving to file... count: 85748
# Saving to file... count: 85816
# Saving to file... count: 85884
# Saving to file... count: 85952
# Saving to file... count: 86020
# Saving to file... count: 86088
# Saving to file... count: 86156
# Saving to file... count: 86224
# Saving to file... count: 86292
# Saving to file... count: 86360
# Saving to file... count: 86428
# Saving to file... count: 86496
# Saving to file... count: 86564
# Saving to file... count: 86632
# Saving to file... count: 86700
# Saving to file... count: 86768
# Saving to file... count: 86836
# Saving to file... count: 86904
# Saving to file... count: 86972
# Saving to file... count: 87040
# Saving to file... count: 87108
# Saving to file... count: 87176
# Saving to file... count: 87244
# Saving to file... count: 87312
# Saving to file... count: 87380
# Saving to file... count: 87448
# Saving to file... count: 87516
# Saving to file... count: 87584
# Saving to file... count: 87652
# Saving to file... count: 87720
# Saving to file... count: 87788
# Saving to file... count: 87856
# Saving to file... count: 87924
# Saving to file... count: 87992
# Saving to file... count: 88060
# Saving to file... count: 88128
# Saving to file... count: 88196
# Saving to file... count: 88264
# Saving to file... count: 88332
# Saving to file... count: 88400
# Saving to file... count: 88468
# Saving to file... count: 88536
# Saving to file... count: 88604
# Saving to file... count: 88672
# Saving to file... count: 88740
# Saving to file... count: 88808
# Saving to file... count: 88876
# Saving to file... count: 88944
# Saving to file... count: 89012
# Saving to file... count: 89080
# Saving to file... count: 89148
# Saving to file... count: 89216
# Saving to file... count: 89284
# Saving to file... count: 89352
# Saving to file... count: 89420
# Saving to file... count: 89488
# Saving to file... count: 89556
# Saving to file... count: 89624
# Saving to file... count: 89692
# Saving to file... count: 89760
# Saving to file... count: 89828
# Saving to file... count: 89896
# Saving to file... count: 89964
# Saving to file... count: 90032
# Saving to file... count: 90100
# Saving to file... count: 90168
# Saving to file... count: 90236
# Saving to file... count: 90304
# Saving to file... count: 90372
# Saving to file... count: 90440
# Saving to file... count: 90508
# Saving to file... count: 90576
# Saving to file... count: 90644
# Saving to file... count: 90712
# Saving to file... count: 90780
# Saving to file... count: 90848
# Saving to file... count: 90916
# Saving to file... count: 90984
# Saving to file... count: 91052
# Saving to file... count: 91120
# Saving to file... count: 91188
# Saving to file... count: 91256
# Saving to file... count: 91324
# Saving to file... count: 91392
# Saving to file... count: 91460
# Saving to file... count: 91528
# Saving to file... count: 91596
# Saving to file... count: 91664
# Saving to file... count: 91732
# Saving to file... count: 91800
# Saving to file... count: 91868
# Saving to file... count: 91936
# Saving to file... count: 92004
# Saving to file... count: 92072
# Saving to file... count: 92140
# Saving to file... count: 92208
# Saving to file... count: 92276
# Saving to file... count: 92344
# Saving to file... count: 92412
# Saving to file... count: 92480
# Saving to file... count: 92548
# Saving to file... count: 92616
# Saving to file... count: 92684
# Saving to file... count: 92752
# Saving to file... count: 92820
# Saving to file... count: 92888
# Saving to file... count: 92956
# Saving to file... count: 93024
# Saving to file... count: 93092
# Saving to file... count: 93160
# Saving to file... count: 93228
# Saving to file... count: 93296
# Saving to file... count: 93364
# Saving to file... count: 93432
# Saving to file... count: 93500
# Saving to file... count: 93568
# Saving to file... count: 93636
# Saving to file... count: 93704
# Saving to file... count: 93772
# Saving to file... count: 93840
# Saving to file... count: 93908
# Saving to file... count: 93976
# Saving to file... count: 94044
# Saving to file... count: 94112
# Saving to file... count: 94180
# Saving to file... count: 94248
# Saving to file... count: 94316
# Saving to file... count: 94384
# Saving to file... count: 94452
# Saving to file... count: 94520
# Saving to file... count: 94588
# Saving to file... count: 94656
# Saving to file... count: 94724
# Saving to file... count: 94792
# Saving to file... count: 94860
# Saving to file... count: 94928
# Saving to file... count: 94996
# Saving to file... count: 95064
# Saving to file... count: 95132
# Saving to file... count: 95200
# Saving to file... count: 95268
# Saving to file... count: 95336
# Saving to file... count: 95404
# Saving to file... count: 95472
# Saving to file... count: 95540
# Saving to file... count: 95608
# Saving to file... count: 95676
# Saving to file... count: 95744
# Saving to file... count: 95812
# Saving to file... count: 95880
# Saving to file... count: 95948
# Saving to file... count: 96016
# Saving to file... count: 96084
# Saving to file... count: 96152
# Saving to file... count: 96220
# Saving to file... count: 96288
# Saving to file... count: 96356
# Saving to file... count: 96424
# Saving to file... count: 96492
# Saving to file... count: 96560
# Saving to file... count: 96628
# Saving to file... count: 96696
# Saving to file... count: 96764
# Saving to file... count: 96832
# Saving to file... count: 96900
# Saving to file... count: 96968
# Saving to file... count: 97036
# Saving to file... count: 97104
# Saving to file... count: 97172
# Saving to file... count: 97240
# Saving to file... count: 97308
# Saving to file... count: 97376
# Saving to file... count: 97444
# Saving to file... count: 97512
# Saving to file... count: 97580
# Saving to file... count: 97648
# Saving to file... count: 97716
# Saving to file... count: 97784
# Saving to file... count: 97852
# Saving to file... count: 97920
# Saving to file... count: 97988
# Saving to file... count: 98056
# Saving to file... count: 98124
# Saving to file... count: 98192
# Saving to file... count: 98260
# Saving to file... count: 98328
# Saving to file... count: 98396
# Saving to file... count: 98464
# Saving to file... count: 98532
# Saving to file... count: 98600
# Saving to file... count: 98668
# Saving to file... count: 98736
# Saving to file... count: 98804
# Saving to file... count: 98872
# Saving to file... count: 98940
# Saving to file... count: 99008
# Saving to file... count: 99076
# Saving to file... count: 99144
# Saving to file... count: 99212
# Saving to file... count: 99280
# Saving to file... count: 99348
# Saving to file... count: 99416
# Saving to file... count: 99484
# Saving to file... count: 99552
# Saving to file... count: 99620
# Saving to file... count: 99688
# Saving to file... count: 99756
# Saving to file... count: 99824
# Saving to file... count: 99892
# Saving to file... count: 99960
# Saving to file... count: 100028
# Saving to file... count: 100096
# Saving to file... count: 100164
# Saving to file... count: 100232
# Saving to file... count: 100300
# Saving to file... count: 100368
# Saving to file... count: 100436
# Saving to file... count: 100504
# Saving to file... count: 100572
# Saving to file... count: 100640
# Saving to file... count: 100708
# Saving to file... count: 100776
# Saving to file... count: 100844
# Saving to file... count: 100912
# Saving to file... count: 100980
# Saving to file... count: 101048
# Saving to file... count: 101116
# Saving to file... count: 101184
# Saving to file... count: 101252
# Saving to file... count: 101320
# Saving to file... count: 101388
# Saving to file... count: 101456
# Saving to file... count: 101524
# Saving to file... count: 101592
# Saving to file... count: 101660
# Saving to file... count: 101728
# Saving to file... count: 101796
# Saving to file... count: 101864
# Saving to file... count: 101932
# Saving to file... count: 102000
# Saving to file... count: 102068
# Saving to file... count: 102136
# Saving to file... count: 102204
# Saving to file... count: 102272
# Saving to file... count: 102340
# Saving to file... count: 102408
# Saving to file... count: 102476
# Saving to file... count: 102544
# Saving to file... count: 102612
# Saving to file... count: 102680
# Saving to file... count: 102748
# Saving to file... count: 102816
# Saving to file... count: 102884
# Saving to file... count: 102952
# Saving to file... count: 103020
# Saving to file... count: 103088
# Saving to file... count: 103156
# Saving to file... count: 103224
# Saving to file... count: 103292
# Saving to file... count: 103360
# Saving to file... count: 103428
# Saving to file... count: 103496
# Saving to file... count: 103564
# Saving to file... count: 103632
# Saving to file... count: 103700
# Saving to file... count: 103768
# Saving to file... count: 103836
# Saving to file... count: 103904
# Saving to file... count: 103972
# Saving to file... count: 104040
# Saving to file... count: 104108
# Saving to file... count: 104176
# Saving to file... count: 104244
# Saving to file... count: 104312
# Saving to file... count: 104380
# Saving to file... count: 104448
# Saving to file... count: 104516
# Saving to file... count: 104584
# Saving to file... count: 104652
# Saving to file... count: 104720
# Saving to file... count: 104788
# Saving to file... count: 104856
# Saving to file... count: 104924
# Saving to file... count: 104992
# Saving to file... count: 105060
# Saving to file... count: 105128
# Saving to file... count: 105196
# Saving to file... count: 105264
# Saving to file... count: 105332
# Saving to file... count: 105400
# ...
# Saving to file... count: 118116
# Saving to file... count: 118184
# Saving to file... count: 118252
# Saving to file... count: 118320
# Saving to file... count: 118388
# Saving to file... count: 118456
# Saving to file... count: 118524
# Saving to file... count: 118592
# Saving to file... count: 118660
# Saving to file... count: 118728
# Saving to file... count: 118796
# Saving to file... count: 118864
# Saving to file... count: 118932
# Saving to file... count: 119000
# Saving to file... count: 119068
# Saving to file... count: 119136
# Saving to file... count: 119204
# Saving to file... count: 119272
# Saving to file... count: 119340
# Saving to file... count: 119408
# Saving to file... count: 119476
# Saving to file... count: 119544
# Saving to file... count: 119612
# Saving to file... count: 119680
# Saving to file... count: 119748
# Saving to file... count: 119816
# Saving to file... count: 119884
# Saving to file... count: 119952
# Saving to file... count: 120020
# Saving to file... count: 120088
# Saving to file... count: 120156
# Saving to file... count: 120224
# Saving to file... count: 120292
# Saving to file... count: 120360
# Saving to file... count: 120428
# Saving to file... count: 120496
# Saving to file... count: 120564
# Saving to file... count: 120632
# Saving to file... count: 120700
# Saving to file... count: 120768
# Saving to file... count: 120836
# Saving to file... count: 120904
# Saving to file... count: 120972
# Saving to file... count: 121040
# Saving to file... count: 121108
# Saving to file... count: 121176
# Saving to file... count: 121244
# Saving to file... count: 121312
# Saving to file... count: 121380
# Saving to file... count: 121448
# Saving to file... count: 121516
# Saving to file... count: 121584
# Saving to file... count: 121652
# Saving to file... count: 121720
# Saving to file... count: 121788
# Saving to file... count: 121856
# Saving to file... count: 121924
# Saving to file... count: 121992
# Saving to file... count: 122060
# Saving to file... count: 122128
# Saving to file... count: 122196
# Saving to file... count: 122264
# Saving to file... count: 122332
# Saving to file... count: 122400
# Saving to file... count: 122468
# Saving to file... count: 122536
# Saving to file... count: 122604
# Saving to file... count: 122672
# Saving to file... count: 122740
# Saving to file... count: 122808
# Saving to file... count: 122876
# Saving to file... count: 122944
# Saving to file... count: 123012
# Saving to file... count: 123080
# Saving to file... count: 123148
# Saving to file... count: 123216
# Saving to file... count: 123284
# Saving to file... count: 123352
# Saving to file... count: 123420
# Saving to file... count: 123488
# Saving to file... count: 123556
# Saving to file... count: 123624
# Saving to file... count: 123692
# Saving to file... count: 123760
# Saving to file... count: 123828
# Saving to file... count: 123896
# Saving to file... count: 123964
# Saving to file... count: 124032
# Saving to file... count: 124100
# Saving to file... count: 124168
# Saving to file... count: 124236
# Saving to file... count: 124304
# Saving to file... count: 124372
# Saving to file... count: 124440
# Saving to file... count: 124508
# Saving to file... count: 124576
# Saving to file... count: 124644
# Saving to file... count: 124712
# Saving to file... count: 124780
# Saving to file... count: 124848
# Saving to file... count: 124916
# Saving to file... count: 124984
# Saving to file... count: 125052
# Saving to file... count: 125120
# Saving to file... count: 125188
# Saving to file... count: 125256
# Saving to file... count: 125324
# Saving to file... count: 125392
# Saving to file... count: 125460
# Saving to file... count: 125528
# Saving to file... count: 125596
# Saving to file... count: 125664
# Saving to file... count: 125732
# Saving to file... count: 125800
# Saving to file... count: 125868
# Saving to file... count: 125936
# Saving to file... count: 126004
# Saving to file... count: 126072
# Saving to file... count: 126140
# Saving to file... count: 126208
# Saving to file... count: 126276
# Saving to file... count: 126344
# Saving to file... count: 126412
# Saving to file... count: 126480
# Saving to file... count: 126548
# Saving to file... count: 126616
# Saving to file... count: 126684
# Saving to file... count: 126752
# Saving to file... count: 126820
# Saving to file... count: 126888
# Saving to file... count: 126956
# Saving to file... count: 127024
# Saving to file... count: 127092
# Saving to file... count: 127160
# Saving to file... count: 127228
# Saving to file... count: 127296
# Saving to file... count: 127364
# Saving to file... count: 127432
# Saving to file... count: 127500
# Saving to file... count: 127568
# Saving to file... count: 127636
# Saving to file... count: 127704
# Saving to file... count: 127772
# Saving to file... count: 127840
# Saving to file... count: 127908
# Saving to file... count: 127976
# Saving to file... count: 128044
# Saving to file... count: 128112
# Saving to file... count: 128180
# Saving to file... count: 128248
# Saving to file... count: 128316
# Saving to file... count: 128384
# Saving to file... count: 128452
# Saving to file... count: 128520
# Saving to file... count: 128588
# Saving to file... count: 128656
# Saving to file... count: 128724
# Saving to file... count: 128792
# Saving to file... count: 128860
# Saving to file... count: 128928
# Saving to file... count: 128996
# Saving to file... count: 129064
# Saving to file... count: 129132
# Saving to file... count: 129200
# Saving to file... count: 129268
# Saving to file... count: 129336
# Saving to file... count: 129404
# Saving to file... count: 129472
# Saving to file... count: 129540
# Saving to file... count: 129608
# Saving to file... count: 129676
# Saving to file... count: 129744
# Saving to file... count: 129812
# Saving to file... count: 129880
# Saving to file... count: 129948
# Saving to file... count: 130016
# Saving to file... count: 130084
# Saving to file... count: 130152
# Saving to file... count: 130220
# Saving to file... count: 130288
# Saving to file... count: 130356
# Saving to file... count: 130424
# Saving to file... count: 130492
# Saving to file... count: 130560
# Saving to file... count: 130628
# Saving to file... count: 130696
# Saving to file... count: 130764
# Saving to file... count: 130832
# Saving to file... count: 130900
# Saving to file... count: 130968
# Saving to file... count: 131036
# Saving to file... count: 131104
# Saving to file... count: 131172
# Saving to file... count: 131240
# Saving to file... count: 131308
# Saving to file... count: 131376
# Saving to file... count: 131444
# Saving to file... count: 131512
# Saving to file... count: 131580
# Saving to file... count: 131648
# Saving to file... count: 131716
# Saving to file... count: 131784
# Saving to file... count: 131852
# Saving to file... count: 131920
# Saving to file... count: 131988
# Saving to file... count: 132056
# Saving to file... count: 132124
# Saving to file... count: 132192
# Saving to file... count: 132260
# Saving to file... count: 132328
# Saving to file... count: 132396
# Saving to file... count: 132464
# Saving to file... count: 132532
# Saving to file... count: 132600
# Saving to file... count: 132668
# Saving to file... count: 132736
# Saving to file... count: 132804
# Saving to file... count: 132872
# Saving to file... count: 132940
# Saving to file... count: 133008
# Saving to file... count: 133076
# Saving to file... count: 133144
# Saving to file... count: 133212
# Saving to file... count: 133280
# Saving to file... count: 133348
# Saving to file... count: 133416
# Saving to file... count: 133484
# Saving to file... count: 133552
# Saving to file... count: 133620
# Saving to file... count: 133688
# Saving to file... count: 133756
# Saving to file... count: 133824
# Saving to file... count: 133892
# Saving to file... count: 133960
# Saving to file... count: 134028
# Saving to file... count: 134096
# Saving to file... count: 134164
# Saving to file... count: 134232
# Saving to file... count: 134300
# Saving to file... count: 134368
# Saving to file... count: 134436
# Saving to file... count: 134504
# Saving to file... count: 134572
# Saving to file... count: 134640
# Saving to file... count: 134708
# Saving to file... count: 134776
# Saving to file... count: 134844
# Saving to file... count: 134912
# Saving to file... count: 134980
# Saving to file... count: 135048
# Saving to file... count: 135116
# Saving to file... count: 135184
# Saving to file... count: 135252
# Saving to file... count: 135320
# Saving to file... count: 135388
# Saving to file... count: 135456
# Saving to file... count: 135524
# Saving to file... count: 135592
# Saving to file... count: 135660
# Saving to file... count: 135728
# Saving to file... count: 135796
# Saving to file... count: 135864
# Saving to file... count: 135932
# Saving to file... count: 136000
# Saving to file... count: 136068
# Saving to file... count: 136136
# Saving to file... count: 136204
# Saving to file... count: 136272
# Saving to file... count: 136340
# Saving to file... count: 136408
# Saving to file... count: 136476
# Saving to file... count: 136544
# Saving to file... count: 136612
# Saving to file... count: 136680
# Saving to file... count: 136748
# Saving to file... count: 136816
# Saving to file... count: 136884
# Saving to file... count: 136952
# Saving to file... count: 137020
# Saving to file... count: 137088
# Saving to file... count: 137156
# Saving to file... count: 137224
# Saving to file... count: 137292
# Saving to file... count: 137360
# Saving to file... count: 137428
# Saving to file... count: 137496
# Saving to file... count: 137564
# Saving to file... count: 137632
# Saving to file... count: 137700
# Saving to file... count: 137768
# Saving to file... count: 137836
# Saving to file... count: 137904
# Saving to file... count: 137972
# Saving to file... count: 138040
# Saving to file... count: 138108
# Saving to file... count: 138176
# Saving to file... count: 138244
# Saving to file... count: 138312
# Saving to file... count: 138380
# Saving to file... count: 138448
# Saving to file... count: 138516
# Saving to file... count: 138584
# Saving to file... count: 138652
# Saving to file... count: 138720
# Saving to file... count: 138788
# Saving to file... count: 138856
# Saving to file... count: 138924
# Saving to file... count: 138992
# Saving to file... count: 139060
# Saving to file... count: 139128
# Saving to file... count: 139196
# Saving to file... count: 139264
# Saving to file... count: 139332
# Saving to file... count: 139400
# Saving to file... count: 139468
# Saving to file... count: 139536
# Saving to file... count: 139604
# Saving to file... count: 139672
# Saving to file... count: 139740
# Saving to file... count: 139808
# Saving to file... count: 139876
# Saving to file... count: 139944
# Saving to file... count: 140012
# Saving to file... count: 140080
# Saving to file... count: 140148
# Saving to file... count: 140216
# Saving to file... count: 140284
# Saving to file... count: 140352
# Saving to file... count: 140420
# Saving to file... count: 140488
# Saving to file... count: 140556
# Saving to file... count: 140624
# Saving to file... count: 140692
# Saving to file... count: 140760
# Saving to file... count: 140828
# Saving to file... count: 140896
# Saving to file... count: 140964
# Saving to file... count: 141032
# Saving to file... count: 141100
# Saving to file... count: 141168
# Saving to file... count: 141236
# Saving to file... count: 141304
# Saving to file... count: 141372
# Saving to file... count: 141440
# Saving to file... count: 141508
# Saving to file... count: 141576
# Saving to file... count: 141644
# Saving to file... count: 141712
# Saving to file... count: 141780
# Saving to file... count: 141848
# Saving to file... count: 141916
# Saving to file... count: 141984
# Saving to file... count: 142052
# Saving to file... count: 142120
# Saving to file... count: 142188
# Saving to file... count: 142256
# Saving to file... count: 142324
# Saving to file... count: 142392
# Saving to file... count: 142460
# Saving to file... count: 142528
# Saving to file... count: 142596
# Saving to file... count: 142664
# Saving to file... count: 142732
# Saving to file... count: 142800
# Saving to file... count: 142868
# Saving to file... count: 142936
# Saving to file... count: 143004
# Saving to file... count: 143072
# Saving to file... count: 143140
# Saving to file... count: 143208
# Saving to file... count: 143276
# Saving to file... count: 143344
# Saving to file... count: 143412
# Saving to file... count: 143480
# Saving to file... count: 143548
# Saving to file... count: 143616
# Saving to file... count: 143684
# Saving to file... count: 143752
# Saving to file... count: 143820
# Saving to file... count: 143888
# Saving to file... count: 143956
# Saving to file... count: 144024
# Saving to file... count: 144092
# Saving to file... count: 144160
# Saving to file... count: 144228
# Saving to file... count: 144296
# Saving to file... count: 144364
# Saving to file... count: 144432
# Saving to file... count: 144500
# Saving to file... count: 144568
# Saving to file... count: 144636
# Saving to file... count: 144704
# Saving to file... count: 144772
# Saving to file... count: 144840
# Saving to file... count: 144908
# Saving to file... count: 144976
# Saving to file... count: 145044
# Saving to file... count: 145112
# Saving to file... count: 145180
# Saving to file... count: 145248
# Saving to file... count: 145316
# Saving to file... count: 145384
# Saving to file... count: 145452
# Saving to file... count: 145520
# Saving to file... count: 145588
# Saving to file... count: 145656
# Saving to file... count: 145724
# Saving to file... count: 145792
# Saving to file... count: 145860
# Saving to file... count: 145928
# Saving to file... count: 145996
# Saving to file... count: 146064
# Saving to file... count: 146132
# Saving to file... count: 146200
# Saving to file... count: 146268
# Saving to file... count: 146336
# Saving to file... count: 146404
# Saving to file... count: 146472
# Saving to file... count: 146540
# Saving to file... count: 146608
# Saving to file... count: 146676
# Saving to file... count: 146744
# Saving to file... count: 146812
# Saving to file... count: 146880
# Saving to file... count: 146948
# Saving to file... count: 147016
# Saving to file... count: 147084
# Saving to file... count: 147152
# Saving to file... count: 147220
# Saving to file... count: 147288
# Saving to file... count: 147356
# Saving to file... count: 147424
# Saving to file... count: 147492
# Saving to file... count: 147560
# Saving to file... count: 147628
# Saving to file... count: 147696
# Saving to file... count: 147764
# Saving to file... count: 147832
# Saving to file... count: 147900
# Saving to file... count: 147968
# Saving to file... count: 148036
# Saving to file... count: 148104
# Saving to file... count: 148172
# Saving to file... count: 148240
# Saving to file... count: 148308
# Saving to file... count: 148376
# Saving to file... count: 148444
# Saving to file... count: 148512
# Saving to file... count: 148580
# Saving to file... count: 148648
# Saving to file... count: 148716
# Saving to file... count: 148784
# Saving to file... count: 148852
# Saving to file... count: 148920
# Saving to file... count: 148988
# Saving to file... count: 149056
# Saving to file... count: 149124
# Saving to file... count: 149192
# Saving to file... count: 149260
# Saving to file... count: 149328
# Saving to file... count: 149396
# Saving to file... count: 149464
# Saving to file... count: 149532
# Saving to file... count: 149600
# Saving to file... count: 149668
# Saving to file... count: 149736
# Saving to file... count: 149804
# Saving to file... count: 149872
# Saving to file... count: 149940
# Saving to file... count: 150008
# Saving to file... count: 150076
# Saving to file... count: 150144
# Saving to file... count: 150212
# Saving to file... count: 150280
# Saving to file... count: 150348
# Saving to file... count: 150416
# Saving to file... count: 150484
# Saving to file... count: 150552
# Saving to file... count: 150620
# Saving to file... count: 150688
# Saving to file... count: 150756
# Saving to file... count: 150824
# Saving to file... count: 150892
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-5a134aa788d5> in <module>
#     117     if ((countSave == save_iter) or (count == len(list_event))):
#     118         print(f'Saving to file... count: {count}')
# --> 119         SaveToFile(signal_dataset, label_dataset, signal_file[count//data_per_file], label_file[count//data_per_file])
#     120
#     121         # start again
#
# IndexError: tuple index out of range

# %%
print(temp_label_2.shape)
print(temp_signal.shape)
# Out:
# (7380,)
# (7380, 100, 6)

# %%
print(temp_label_2[6020])
print(temp_signal[1000])
# Out:
# 0
# [[-4.84261137e+02 -1.08312566e+02  7.57494566e+01  1.55479436e+03
#    1.24005039e+02 -3.71006383e+02]
#  [ 9.02333729e+02 -3.86946356e+01 -5.11743879e+02  1.23937887e+03
#    1.67250583e+02 -3.26801926e+01]
#  [ 1.78953488e+03  1.64800035e+01 -1.02362276e+03  2.16006777e+03
#    3.10133413e+02 -5.10122164e+02]
#  [ 2.13672071e+03  2.23281161e+02 -1.20022708e+03  1.23423145e+03
#    2.62975554e+02 -5.56820471e+01]
#  [ 2.09024913e+03  5.48018002e+02 -9.04501674e+02  2.41585459e+03
#    4.88683156e+02 -6.34563579e+02]
#  [ 1.94138148e+03  8.06014392e+02 -2.69951945e+02  1.73543824e+03
#    2.46333816e+02 -1.87665358e+02]
#  [ 1.98189861e+03  8.60058638e+02  3.47075858e+02  4.54975062e+03
#   -3.55157574e+02 -6.04690078e+02]
#  [ 2.31786757e+03  6.87586848e+02  6.08381846e+02  1.98853481e+03
#    2.33491746e+03  2.21163836e+02]
#  [ 2.79514934e+03  3.61202279e+02  4.51621225e+02  7.17191025e+03
#    2.16033595e+03 -1.40283692e+03]
#  [ 3.07346621e+03  5.48486393e+01  1.08077418e+02 -6.97568184e+03
#   -3.43226952e+02  7.56768459e+01]
#  [ 2.81884705e+03 -3.81147233e+01 -1.26517744e+02 -4.11493088e+03
#   -4.44770945e+03 -3.12966041e+03]
#  [ 1.92614287e+03  1.12727661e+02 -1.06179397e+02 -3.79601090e+03
#    5.40545701e+02  2.85980275e+03]
#  [ 5.88080490e+02  3.37554747e+02  1.15792343e+02 -4.22918558e+03
#   -2.45042943e+03 -2.19385652e+03]
#  [-8.51270895e+02  4.14532752e+02  3.49433259e+02 -2.49275256e+03
#   -6.40405013e+02  1.48750703e+03]
#  [-2.09904909e+03  1.93588657e+02  4.16019088e+02 -1.60535763e+03
#    1.58780573e+03  3.88844121e+02]
#  [-2.98612064e+03 -3.32782956e+02  3.13103551e+02  3.70629866e+03
#    2.90139145e+02 -1.59009418e+03]
#  [-3.42251778e+03 -9.91167932e+02  1.91081209e+02 -2.89306422e+03
#   -1.32784043e+02  5.17869432e+02]
#  [-3.40141900e+03 -1.52185598e+03  1.45293863e+02  2.52855928e+03
#    1.13574950e+03  3.24788814e+02]
#  [-3.03877594e+03 -1.73480353e+03  1.17572926e+02 -1.86804417e+02
#   -1.12580629e+03 -1.02617995e+02]
#  [-2.49064375e+03 -1.55854029e+03  1.11045927e+01  1.45269680e+03
#   -3.72242478e+02 -1.22443966e+03]
#  [-1.82165365e+03 -1.01257221e+03 -1.89969278e+02  6.27806353e+02
#    4.45871355e+02  8.26546744e+02]
#  [-1.02953279e+03 -2.26102117e+02 -4.23642452e+02 -2.03524761e+03
#   -7.31343666e+02  4.24843078e+02]
#  [-1.88055431e+02  5.23906149e+02 -5.84332100e+02  2.60438923e+03
#   -8.08710484e+02  2.04585047e+02]
#  [ 5.26321326e+02  9.27756798e+02 -5.47263577e+02 -5.61635921e+02
#   -2.55556299e+03  5.47880834e+02]
#  [ 1.00255769e+03  8.97645082e+02 -2.76466391e+02 -1.39196044e+03
#   -2.46106618e+02  7.69184619e+02]
#  [ 1.34449129e+03  6.58975450e+02  5.68939378e+01 -1.67857247e+03
#    1.79082699e+03 -6.12397980e+00]
#  [ 1.75839245e+03  5.40071400e+02  1.93255845e+02 -5.77869963e+02
#    1.51293537e+03  1.34852324e+03]
#  [ 2.25391028e+03  6.94274664e+02  7.13673454e+01  9.47924681e+00
#   -9.81607794e+02 -1.20025025e+02]
#  [ 2.53909295e+03  1.01260560e+03 -1.01481723e+02  1.92623887e+02
#    5.95766757e+02  5.50260898e+02]
#  [ 2.29714310e+03  1.24126647e+03 -8.36820375e+01 -1.83953457e+03
#   -4.77289580e+01  1.22155283e+02]
#  [ 1.54323715e+03  1.17539426e+03  1.60367123e+02 -3.66499177e+02
#    8.50485346e+02  6.87110820e+02]
#  [ 6.72981074e+02  8.03038561e+02  4.43625344e+02 -1.76135118e+02
#   -1.10892740e+02  1.07126783e+03]
#  [ 1.38940834e+02  2.67961534e+02  5.40592631e+02 -1.22684823e+03
#   -8.61173169e+02  4.45166762e+02]
#  [ 5.64718569e+01 -3.12341604e+02  3.96186580e+02 -6.18130414e+01
#    6.37161680e+02 -2.19960823e+02]
#  [ 1.57466855e+02 -8.85906579e+02  1.65115113e+02 -1.20680945e+02
#    3.35682601e+02 -9.14982495e+01]
#  [ 1.04658560e+02 -1.32103054e+03  4.64859056e+01  2.85681459e+02
#   -2.07156586e+02 -9.13552954e+01]
#  [-2.17144819e+02 -1.39992792e+03  9.73179411e+01 -2.48008004e+02
#    4.27077947e+02  7.63072294e+01]
#  [-6.65232339e+02 -1.02012294e+03  2.09593880e+02 -6.45614997e+02
#   -3.81107488e+02  1.76172655e+02]
#  [-1.03052210e+03 -3.53199697e+02  2.14516397e+02 -3.17996038e+02
#   -1.38303299e+02 -9.82676689e+01]
#  [-1.23862533e+03  1.92485378e+02 -3.92193526e+00 -8.91910717e+00
#   -9.28513784e+01  7.89650048e+01]
#  [-1.30414778e+03  2.23824840e+02 -4.02221465e+02 -1.76485115e+02
#    2.11371016e+02  1.31473034e+01]
#  [-1.17689851e+03 -3.15856853e+02 -7.44501552e+02  4.03560019e+00
#   -3.13109411e+01  3.12250877e+01]
#  [-8.04891844e+02 -1.04960857e+03 -7.70786627e+02 -6.88411779e+01
#   -2.13355336e+01 -5.18472623e+01]
#  [-3.07255990e+02 -1.41981691e+03 -4.55363159e+02 -8.72719872e+01
#    4.17066121e+01 -2.31941704e+01]
#  [ 4.64397932e+01 -1.10812750e+03 -4.52725564e+01 -2.34896209e+02
#    1.53817389e+01  1.16693276e+02]
#  [ 2.33072739e+01 -2.72100877e+02  1.92841328e+02 -8.00545236e+01
#    2.07166234e-01  2.23138559e+01]
#  [-4.01858219e+02  6.12378887e+02  2.13459595e+02 -1.52238612e+02
#   -3.02883621e+01  8.87802370e+01]
#  [-9.56250112e+02  1.12286672e+03  1.53499801e+02 -1.31913439e+02
#   -5.19252032e+01 -5.08404629e+01]
#  [-1.15094110e+03  1.11542417e+03  1.26507030e+02 -8.63718167e+01
#    9.51045607e+01  3.06605073e+01]
#  [-6.22712168e+02  7.08902455e+02  1.20232802e+02 -1.38282336e+02
#   -9.85862583e+01  4.89891966e+00]
#  [ 4.99067054e+02  1.96384988e+02  6.25412266e+01 -8.68327842e+01
#    2.64269219e+01  1.42214747e+01]
#  [ 1.63763694e+03 -6.70311270e+01 -6.86296660e+01 -4.74048524e+01
#   -8.58987165e+00 -9.69683571e+00]
#  [ 2.24286891e+03  1.32333221e+02 -2.09907598e+02 -9.85627968e+01
#    2.50248656e+01  4.32799132e+01]
#  [ 2.17736260e+03  6.75028481e+02 -2.74985339e+02 -8.01356874e+01
#   -2.58042316e+01  9.04688338e-01]
#  [ 1.68112915e+03  1.15104718e+03 -2.20394853e+02 -8.09349722e+01
#    2.92431114e+01  4.67871047e+01]
#  [ 1.09500811e+03  1.19699238e+03 -3.70025424e+01 -4.34281752e+01
#   -4.03419199e+01  2.94902598e+01]
#  [ 6.09350223e+02  8.32502366e+02  2.55683223e+02 -8.43609144e+01
#   -3.49296797e+00  3.21497770e+01]
#  [ 1.91887802e+02  3.83612435e+02  5.62064326e+02 -5.24625306e+01
#   -3.08082803e+01 -4.50436633e-02]
#  [-2.60526408e+02  8.11634278e+01  7.28190570e+02 -8.39171643e+01
#    5.65029251e+00  3.14786054e+01]
#  [-7.35623318e+02 -1.33589019e+02  6.63149962e+02 -4.16323092e+01
#   -3.06653728e+01  2.96603481e+00]
#  [-1.10778665e+03 -4.10535116e+02  3.96658837e+02 -6.84653394e+01
#    6.99898961e+00  2.54724157e+01]
#  [-1.28918188e+03 -7.55412689e+02  1.52254671e+01 -4.40089626e+01
#   -2.57584347e+01  3.76979857e+00]
#  [-1.31630797e+03 -1.04454210e+03 -3.83968739e+02 -6.62763512e+01
#    1.13599235e+00  2.48251862e+01]
#  [-1.26256796e+03 -1.15771078e+03 -7.00495862e+02 -4.11993907e+01
#   -2.64383507e+01  2.30287028e+00]
#  [-1.14096662e+03 -1.06139442e+03 -8.73333962e+02 -5.56578664e+01
#    5.24966789e+00  2.08574994e+01]
#  [-9.71641551e+02 -8.64419182e+02 -8.95813164e+02 -3.66356534e+01
#   -1.79638116e+01  1.29129853e+00]
#  [-8.38082345e+02 -7.42548045e+02 -7.50344743e+02 -4.98991970e+01
#    5.18814975e+00  2.01807469e+01]
#  [-7.36496850e+02 -6.84202351e+02 -3.95783471e+02 -3.26914208e+01
#   -1.68617837e+01  1.68995675e+00]
#  [-4.67145227e+02 -4.21982526e+02  1.14543214e+02 -5.05586872e+01
#    3.48939055e+00  1.80729465e+01]
#  [ 1.51567547e+02  2.37745845e+02  5.79809726e+02 -3.15114243e+01
#   -1.60593578e+01  2.46720316e+00]
#  [ 9.84070221e+02  1.08468449e+03  8.08125853e+02 -4.26014461e+01
#    6.47497512e+00  1.73615487e+01]
#  [ 1.60162577e+03  1.62061909e+03  7.80941816e+02 -2.82927160e+01
#   -1.52986145e+01  2.18265856e+00]
#  [ 1.63086746e+03  1.51016126e+03  6.24426607e+02 -3.84978587e+01
#    4.98304706e+00  1.58147259e+01]
#  [ 1.06804629e+03  8.53420984e+02  4.87062151e+02 -2.64746121e+01
#   -1.35758484e+01  1.53544442e+00]
#  [ 2.81590869e+02  4.54419913e+01  4.57751556e+02 -3.50143773e+01
#    3.20284854e+00  1.39485352e+01]
#  [-2.30865237e+02 -5.14854097e+02  5.07416112e+02 -2.38679543e+01
#   -1.27454780e+01  1.62597732e+00]
#  [-1.31911906e+02 -6.36199909e+02  4.77620937e+02 -3.15607125e+01
#    3.81681083e+00  1.27372580e+01]
#  [ 5.36968644e+02 -4.41338371e+02  1.96659229e+02 -2.07785115e+01
#   -1.10710401e+01  1.48522165e+00]
#  [ 1.36242083e+03 -2.70223755e+02 -3.44012133e+02 -2.80636853e+01
#    3.27359753e+00  1.14541732e+01]
#  [ 1.86414304e+03 -3.66365886e+02 -9.41300156e+02 -1.86487400e+01
#   -9.89058302e+00  1.39521680e+00]
#  [ 1.82643731e+03 -6.21850104e+02 -1.33528930e+03 -2.52164309e+01
#    3.03299500e+00  1.02028964e+01]
#  [ 1.34355520e+03 -6.83571193e+02 -1.40774027e+03 -1.65471059e+01
#   -8.67403463e+00  1.19287406e+00]
#  [ 6.03384161e+02 -3.66232282e+02 -1.21579189e+03 -2.22775751e+01
#    2.66023141e+00  9.16379069e+00]
#  [-3.22058474e+02  1.04238586e+02 -8.67035195e+02 -1.45927939e+01
#   -7.64756957e+00  1.06674190e+00]
#  [-1.42479348e+03  3.51814231e+02 -4.21275940e+02 -1.94555835e+01
#    2.30196360e+00  7.97271933e+00]
#  [-2.53980272e+03  2.74176613e+02  7.18118674e+01 -1.27194592e+01
#   -6.64132716e+00  9.70040527e-01]
#  [-3.32930095e+03  9.48726275e+01  5.11529159e+02 -1.67998049e+01
#    2.02188533e+00  6.90464469e+00]
#  [-3.50466039e+03  6.90146171e+01  8.11511689e+02 -1.08689108e+01
#   -5.65913742e+00  8.35400983e-01]
#  [-2.97548449e+03  2.56813421e+02  1.00848078e+03 -1.42325346e+01
#    1.70697417e+00  5.85427921e+00]
#  [-1.85130780e+03  5.60612815e+02  1.21223209e+03 -9.10081525e+00
#   -4.74191414e+00  6.94802454e-01]
#  [-4.37696551e+02  8.60952922e+02  1.41945409e+03 -1.17400850e+01
#    1.41354398e+00  4.83318683e+00]
#  [ 8.07986370e+02  1.04862918e+03  1.44812258e+03 -7.37846947e+00
#   -3.84300995e+00  5.67145525e-01]
#  [ 1.50953285e+03  1.00855252e+03  1.11374637e+03 -9.31738268e+00
#    1.12212684e+00  3.83939588e+00]
#  [ 1.63664592e+03  6.88956476e+02  4.43243822e+02 -5.69893678e+00
#   -2.96479889e+00  4.39703829e-01]
#  [ 1.46009136e+03  1.64610980e+02 -3.24218434e+02 -6.94430696e+00
#    8.37074597e-01  2.86333379e+00]
#  [ 1.27360404e+03 -4.04406155e+02 -9.27971754e+02 -4.04939500e+00
#   -2.10503725e+00  3.13099756e-01]
#  [ 1.22639881e+03 -8.33498598e+02 -1.24970501e+03 -4.60872423e+00
#    5.55853413e-01  1.90113083e+00]
#  [ 1.30691123e+03 -9.67660968e+02 -1.31907755e+03 -2.42114154e+00
#   -1.25805396e+00  1.87494151e-01]
#  [ 1.37953141e+03 -7.66583126e+02 -1.21264721e+03 -2.29814425e+00
#    2.77276331e-01  9.48247238e-01]
#  [ 1.29515810e+03 -3.41866200e+02 -9.71858196e+02 -8.05634413e-01
#   -4.18525142e-01  6.24354482e-02]]

# %% [markdown]
# ## Proses penyimpanan dataset

# %%
a_file = "D:/S3_project/S Picker/Cooked_Dataset/Dataset100Hz/signal_dataset_20F_100Hz_01.npy"
np.save(a_file, signal_dataset)

b_file = "D:/S3_project/S Picker/Cooked_Dataset/Dataset100Hz/label_dataset_20F_100Hz_01.npy"
np.save(b_file, label_dataset)

# %% [markdown]
# Penyimpanan setelah dilakukan scaling

# %%
#Scaling for the Signals
signal_dataset_time = np.delete(signal_dataset, [3,4,5], 2)
signal_dataset_freq = np.delete(signal_dataset, [0,1,2], 2)

orig_shape = signal_dataset.shape
signal_dataset = None

from sklearn.preprocessing import StandardScaler
scalers = {}
for i in range(orig_shape[0]):
    scalers[i] = StandardScaler()
    signal_dataset_time[i][:][:] = scalers[i].fit_transform(signal_dataset_time[i][:][:]) 

scalers = {}
for i in range(orig_shape[0]):
    scalers[i] = StandardScaler()
    signal_dataset_freq[i][:][:] = scalers[i].fit_transform(signal_dataset_freq[i][:][:]) 

signal_dataset_scaled = np.append(signal_dataset_time, signal_dataset_freq, axis = 2)

# %%
a_file = "D:/S3_project/S Picker/Cooked_Dataset/Dataset100Hz/signal_dataset_20F_100Hz_Scaled_01.npy"
np.save(a_file, signal_dataset_scaled)

b_file = "D:/S3_project/S Picker/Cooked_Dataset/Dataset100Hz/label_dataset_20F_100Hz_Scaled_01.npy"
np.save(b_file, label_dataset)
